# %% [markdown]
# # Answering Business Questions for Chinook Record Store Using SQL

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In this project we are going to answer business questions related to *Chinook Record Store* using SQL. Chinook database is provided as a SQLite database file. Down below we impliment the code which connects the Jupyter Notebook to the Chinook databse.

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %% [markdown]
# Further we will run few queries in order to familiarize ourselves with the data.First we will look at the list of all tables in the database.

# %%
# %%sql
# SELECT name, type
#   FROM sqlite_master
#  WHERE type IN ("table", "view");
# Out:
# Done.
# [('album', 'table'),
#  ('artist', 'table'),
#  ('customer', 'table'),
#  ('employee', 'table'),
#  ('genre', 'table'),
#  ('invoice', 'table'),
#  ('invoice_line', 'table'),
#  ('media_type', 'table'),
#  ('playlist', 'table'),
#  ('playlist_track', 'table'),
#  ('track', 'table'),
#  ('counts', 'view'),
#  ('num_of_cstmrs', 'view'),
#  ('tot_sales_val', 'view')]

# %% [markdown]
# As we can see from the above list there are total of *eleven* tables in our database. We will look at couple of tables from the above list and get familiar with the data.

# %%
# %%sql
# SELECT *
#   FROM album
#  LIMIT 5;
# Out:
# Done.
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3)]

# %%
# %%sql
# SELECT *
#   FROM playlist
#  LIMIT 5;
# Out:
# Done.
# [(1, 'Music'),
#  (2, 'Movies'),
#  (3, 'TV Shows'),
#  (4, 'Audiobooks'),
#  (5, '90’s Music')]

# %% [markdown]
# ## 2.Finding Which Genres Sell Best in USA

# %% [markdown]
# The Chinook record store has signed a deal with a new record label. We have to select first three albums from a list of four, to be added to the store. All four albums are by artists who do not possess any tracks in the store. Below are the artist and genre names.
#
# |*Artist Name*	      |       *Genre*  |
# |---------------------|----------------|
# |Regal	              |        Hip-Hop |
# |Red Tone	          |        Punk    |
# |Meteor and the Girls |  	      Pop  |
# |Slim Jim Bites	      |        Blues   |
#
# The record label specializes in artists from USA. They have given Chinook some money to advertise the new albums in USA. Our objective is to find out which genres sell best in USA.

# %%
# %%sql
# WITH
# Genre_Sold_USA AS
# (
#  SELECT
#     g.name genre,
#     SUM(il.quantity) Sum_Sold
#   FROM genre g
#  LEFT JOIN track t ON t.genre_id = g.genre_id
#  LEFT JOIN invoice_line il ON il.track_id = t.track_id
#  LEFT JOIN invoice i ON i.invoice_id = il.invoice_id
#  LEFT JOIN customer c ON c.customer_id = i.customer_id
#
#  WHERE c.country="USA"
#  GROUP BY 1
#  ORDER BY 2 DESC
#     )
#
# SELECT GSU.genre Genre,
#        GSU.Sum_Sold Absolute_Sold,
#        ROUND(GSU.Sum_Sold*100 / (SELECT TOTAL(GSU.Sum_Sold) FROM Genre_Sold_USA GSU), 2) Percentage_Sold
#   FROM Genre_Sold_USA GSU;
# Out:
# Done.
# [('Rock', 561, 53.38),
#  ('Alternative & Punk', 130, 12.37),
#  ('Metal', 124, 11.8),
#  ('R&B/Soul', 53, 5.04),
#  ('Blues', 36, 3.43),
#  ('Alternative', 35, 3.33),
#  ('Latin', 22, 2.09),
#  ('Pop', 22, 2.09),
#  ('Hip Hop/Rap', 20, 1.9),
#  ('Jazz', 14, 1.33),
#  ('Easy Listening', 13, 1.24),
#  ('Reggae', 6, 0.57),
#  ('Electronica/Dance', 5, 0.48),
#  ('Classical', 4, 0.38),
#  ('Heavy Metal', 3, 0.29),
#  ('Soundtrack', 2, 0.19),
#  ('TV Shows', 1, 0.1)]

# %% [markdown]
# From the above list it is clear that *Rock* sells best in USA, i.e. *53.38%* (more than half). But we do not have it in the record label.
#
# **Below we list all the four genres in the record label according to their sales percentage (highest to lowest) in USA.**
#
#  - Highest of these is *Alternate & Punk*. It has a sales of *12.37%*. And *Punk* is in the record label.
#  - Next highest is *Blues* with the sales of *3.43%*.
#  - Third highest is *Pop* with the sales of *2.09%*.
#  - Last is *Hip-Hop/Rap* with only *1.9%* sales.
#
#
#  **Based on our observation of the sales percentage, we recommend these three artists:-**
#
#  1.Red Tone
#
#  2.Slim Jim Bites
#
#  3.Meteor and the Girls

# %% [markdown]
# ## 3. Analyzing Variance in Employee (Sales Support Agent) Performance

# %% [markdown]
# Each customer for the Chinook store gets assigned to a *sales support agent* from the company, when they purchase tracks. Here we will analyze if any sales support agent is performing better/worse than others. We will also consider any column (information) from the *employee* table that is indicative of variance in their performance.

# %%
# %%sql
# SELECT e.first_name || " " || e.last_name Employee_Name,
#        e.title Title,
#        e.hire_date Hire_Date,
#        e.birthdate Birthdate,
#        max(invoice_date) latest_invoice_date,
#        ROUND(SUM(i.total), 2) Total_Sales_$,
#        ROUND(SUM(i.total) * 100 /(SELECT SUM(total)
#                                     FROM invoice), 2) Sales_Perc
#
#   FROM employee e
#
# LEFT JOIN customer c ON c.support_rep_id = e.employee_id
# LEFT JOIN invoice i ON i.customer_id = c.customer_id
#
# WHERE Title = "Sales Support Agent"
# GROUP BY 1
# ORDER BY 6 DESC;
# Out:
# Done.
# [('Jane Peacock', 'Sales Support Agent', '2017-04-01 00:00:00', '1973-08-29 00:00:00', '2020-12-30 00:00:00', 1731.51, 36.77),
#  ('Margaret Park', 'Sales Support Agent', '2017-05-03 00:00:00', '1947-09-19 00:00:00', '2020-12-29 00:00:00', 1584.0, 33.63),
#  ('Steve Johnson', 'Sales Support Agent', '2017-10-17 00:00:00', '1965-03-03 00:00:00', '2020-12-20 00:00:00', 1393.92, 29.6)]

# %% [markdown]
# From the above table we see that *Jane Peacock* holds the highest sales amount of *~ \$1731*, followed by *Margaret Park* with *~ \$1584*. Last is *Steve Johnson* with *~ \$1394* sales amount.
#
# If we look at their *hire_date*, *Jane Peacock* joined first i.e. on *4th April 2017*. *Margaret Park* joined in a month's time i.e. on *3rd May 2017*. Where as *Steve Johnson* joined a few month's later, i.e. on *17th October 2017*. If we look at the latest *invoice date* of all the three, there is not much difference.
#
# We observe that both *Jane Peacock* and *Steve Johnson* hold better sales value compared to *Margaret Park*, evethough *Jane Peacock* joined a month earlier and *Steve Johnson* joined five months later than her. If we Look at the birthdate, both *Jane Peacock* and *Steve Johnson* are younger to *Margaret Park* and *Jane Peacock* is younger to *Steve Johnson*. From this we perceive that the age can also have an effect on the performance of the employees. i.e. younger employees  perform better than older employees.

# %% [markdown]
# ## 4. Analyzing the Sales Data for Customers from Each Country

# %% [markdown]
# In this section we are going to analyze the sales data for customers from each different country. Here we are going to calculate
#  - Total number of customers
#  - Total value of sales
#  - Average value of sales per customer
#  - Average order value
#
# For each country.
#
# As there are many countries with only one customer, we will group these customers into **Others** in our analysis and put them last in the table.
#
# First let us calculate the *total number of customers* for each country.

# %%
# %%sql
# WITH num_of_cstmrs AS
# (SELECT country Country,
#        count(first_name) No_of_customers
#   FROM customer
# GROUP BY 1
# ORDER BY 2 DESC)
#
# SELECT * FROM num_of_cstmrs;
# Out:
# Done.
# [('USA', 13),
#  ('Canada', 8),
#  ('Brazil', 5),
#  ('France', 5),
#  ('Germany', 4),
#  ('United Kingdom', 3),
#  ('Czech Republic', 2),
#  ('India', 2),
#  ('Portugal', 2),
#  ('Argentina', 1),
#  ('Australia', 1),
#  ('Austria', 1),
#  ('Belgium', 1),
#  ('Chile', 1),
#  ('Denmark', 1),
#  ('Finland', 1),
#  ('Hungary', 1),
#  ('Ireland', 1),
#  ('Italy', 1),
#  ('Netherlands', 1),
#  ('Norway', 1),
#  ('Poland', 1),
#  ('Spain', 1),
#  ('Sweden', 1)]

# %% [markdown]
# First we will calculate the *total value of sales*, *average value of sales per customer* and *average order value* for all countries. Then we can seperate the countries with only one customer, aggregate their values and rename them as *Others*. Later we can club the countries with more than one customer and countries with one customer into one table.

# %%
# %%sql
# WITH tot_sales_val AS
# (SELECT c.country Country,
#        ROUND(SUM(i.total), 2) Tot_Value_Sales,
#        ROUND(AVG(i.total), 2) Avg_Order_Value,
#        ROUND(SUM(i.total)/(SELECT COUNT(DISTINCT(customer_id)) FROM invoice), 2) Avg_Sales_Value_per_Customer
#
#  FROM customer c
# INNER JOIN invoice i ON i.customer_id = c.customer_id
# GROUP BY 1
# ORDER BY 2 DESC),
#
# sales_data_1 AS
# (SELECT noc.Country,
#        noc.No_of_customers,
#        tsv.Tot_Value_Sales,
#        tsv.Avg_Sales_Value_per_Customer,
#        tsv.Avg_Order_Value
#   FROM Num_of_cstmrs noc
# INNER JOIN tot_sales_val tsv ON tsv.Country=noc.Country
#  WHERE noc.No_of_customers > 1),
#
# sales_data_2 AS
# (SELECT CASE
#        WHEN noc.No_of_customers=1 THEN "Others"
#        END AS
#        Country,
#        noc.No_of_customers,
#        ROUND(AVG(tsv.Tot_Value_Sales),2) Tot_Value_Sales,
#        ROUND(AVG(tsv.Avg_Sales_Value_per_Customer),2) AVG_Sales_Value_per_Customer,
#        ROUND(AVG(tsv.Avg_Order_Value),2) AVG_Order_Value
#   FROM Num_of_cstmrs noc
# INNER JOIN tot_sales_val tsv ON tsv.Country=noc.Country
#  WHERE noc.No_of_customers = 1),
#
# tot_sales_data AS
# (SELECT *
# FROM sales_data_1
# UNION
# SELECT *
# FROM sales_data_2)
#
# SELECT *
#   FROM tot_sales_data
# ORDER BY 3 DESC;
# Out:
# Done.
# [('USA', 13, 1040.49, 17.64, 7.94),
#  ('Canada', 8, 535.59, 9.08, 7.05),
#  ('Brazil', 5, 427.68, 7.25, 7.01),
#  ('France', 5, 389.07, 6.59, 7.78),
#  ('Germany', 4, 334.62, 5.67, 8.16),
#  ('Czech Republic', 2, 273.24, 4.63, 9.11),
#  ('United Kingdom', 3, 245.52, 4.16, 8.77),
#  ('Portugal', 2, 185.13, 3.14, 6.38),
#  ('India', 2, 183.15, 3.1, 8.72),
#  ('Others', 1, 73.0, 1.24, 7.44)]

# %% [markdown]
# Above table is in the descending order of *total value of sales*. And *Others* (countries with only one customer) is at the bottom of the table.
#
# Here we observe that USA is on top of the list with *13* customers and with ~ \$1040 total value of sales. Next is CANADA with *8* customers and ~ \$535 total value of sales.

# %% [markdown]
# ## 5. Analyzing the Invoice Data: Album Purchase Vs Individual Purchase of Tracks

# %% [markdown]
# Chinook store allows the customers to make purchases in two ways:
# * purchase a whole album
# * purchase a collection of one or more individual tracks
#
# But the store does not allow the customers to purchase a whole album and then add individual tracks to the same purchase. The cost of whole album is same as that of each track if purchased seperately.
#
# The company wants to change their policy inorder to save money. The new stratergy it wants to consider is to purchase only the popular tracks from each album from the record companies, instead of purchasing every track from an album.
#
# Our task is to calculate the percentage of individual tracks purchased Vs percentage of whole album purchased by the customers. This analysis can help the company understand the impact of new statergy on overall revenue.
#
# We are going to accomplish this task by analyzing the tracks from invoice and then comparing it with the album.
#
# First let us look at the Number of invoices.

# %%
# %%sql
# SELECT MAX(invoice_id) total_invoice
#   FROM invoice_line;
# Out:
# Done.
# [(614,)]

# %% [markdown]
# From the above table we observe that there are total of *614* invoices. Further we will compare the tracks from invoice with that of albums.

# %%
# %%sql
# WITH com_pur AS
# (SELECT il.invoice_id invoice_id, il.track_id Pur_tracks, t.album_id album_id
#   FROM track t
# INNER JOIN invoice_line il ON il.track_id = t.track_id
# ORDER BY 1)
#
# SELECT *
#   FROM com_pur;
# Out:
# Done.
# [(1, 1158, 91),
#  (1, 1159, 91),
#  (1, 1160, 91),
#  (1, 1161, 91),
#  (1, 1162, 91),
#  (1, 1163, 91),
#  (1, 1164, 91),
#  (1, 1165, 91),
#  (1, 1166, 91),
#  (1, 1167, 91),
#  (1, 1168, 91),
#  (1, 1169, 91),
#  (1, 1170, 91),
#  (1, 1171, 91),
#  (1, 1172, 91),
#  (1, 1173, 91),
#  (2, 3476, 322),
#  (2, 482, 39),
#  (2, 2701, 218),
#  (2, 1641, 134),
#  (2, 1119, 73),
#  (2, 2324, 190),
#  (2, 201, 20),
#  (2, 819, 66),
#  (2, 392, 34),
#  (2, 2651, 215),
#  (3, 2516, 203),
#  (3, 2646, 214),
#  (4, 3448, 314),
#  (4, 2560, 207),
#  (4, 3336, 260),
#  (4, 829, 67),
#  (4, 1872, 153),
#  (4, 748, 58),
#  (4, 1778, 146),
#  (4, 2514, 203),
#  (5, 1986, 163),
#  (5, 1987, 163),
#  (5, 1988, 163),
#  (5, 1989, 163),
#  (5, 1990, 163),
#  (5, 1991, 163),
#  (5, 1992, 163),
#  (5, 1993, 163),
#  (5, 1994, 163),
#  (5, 1995, 163),
#  (5, 1996, 163),
#  (5, 1997, 163),
#  (5, 1998, 163),
#  (5, 1999, 163),
#  (5, 2000, 163),
#  (5, 2001, 163),
#  (5, 2002, 163),
#  (6, 1045, 83),
#  (6, 30, 5),
#  (7, 3477, 322),
#  (7, 3439, 305),
#  (7, 1102, 87),
#  (7, 711, 55),
#  (7, 1988, 163),
#  (7, 3024, 239),
#  (7, 834, 67),
#  (7, 2596, 211),
#  (7, 1343, 106),
#  (7, 2644, 214),
#  (7, 42, 6),
#  (8, 2231, 183),
#  (8, 2509, 203),
#  (8, 81, 9),
#  (8, 1758, 145),
#  (8, 1455, 118),
#  (8, 2946, 233),
#  (8, 574, 46),
#  (8, 1752, 144),
#  (8, 2263, 185),
#  (8, 1560, 125),
#  (9, 206, 21),
#  (9, 3456, 321),
#  (9, 1041, 83),
#  (9, 1279, 101),
#  (9, 2098, 173),
#  (9, 3399, 271),
#  (9, 1983, 162),
#  (9, 993, 79),
#  (9, 196, 20),
#  (10, 2663, 215),
#  (10, 3290, 257),
#  (11, 2597, 211),
#  (11, 2203, 181),
#  (11, 2420, 197),
#  (11, 2643, 214),
#  (11, 3072, 243),
#  (11, 1138, 89),
#  (11, 2391, 195),
#  (11, 2257, 185),
#  (11, 610, 49),
#  (11, 1419, 115),
#  (11, 3452, 318),
#  (12, 1463, 118),
#  (12, 690, 54),
#  (12, 2663, 215),
#  (12, 92, 10),
#  (13, 2553, 206),
#  (14, 541, 42),
#  (15, 3050, 241),
#  (15, 1489, 120),
#  (15, 807, 65),
#  (15, 3336, 260),
#  (16, 2160, 178),
#  (16, 875, 70),
#  (16, 83, 9),
#  (16, 16, 4),
#  (16, 1756, 145),
#  (16, 3460, 321),
#  (16, 93, 10),
#  (16, 24, 5),
#  (16, 21, 4),
#  (17, 2400, 195),
#  (17, 1610, 131),
#  (17, 1973, 162),
#  (17, 2553, 206),
#  (17, 59, 7),
#  (17, 2270, 185),
#  (17, 55, 7),
#  (17, 2564, 207),
#  (17, 2171, 179),
#  (17, 2522, 203),
#  (17, 1419, 115),
#  (18, 1027, 82),
#  (18, 3142, 141),
#  (18, 1583, 127),
#  (18, 1752, 144),
#  (18, 2736, 221),
#  (19, 105, 11),
#  (19, 2669, 216),
#  (19, 1784, 146),
#  (19, 3460, 321),
#  (19, 2640, 214),
#  (19, 1310, 103),
#  (19, 2510, 203),
#  (20, 905, 72),
#  (20, 102, 11),
#  (20, 3336, 260),
#  (20, 1132, 88),
#  (20, 337, 30),
#  (20, 60, 7),
#  (20, 3357, 267),
#  (20, 3225, 252),
#  (20, 3297, 257),
#  (20, 3297, 257),
#  (21, 1461, 118),
#  (21, 2556, 207),
#  (21, 1434, 116),
#  (21, 3135, 141),
#  (21, 1473, 119),
#  (21, 1502, 121),
#  (21, 13, 1),
#  (21, 2971, 235),
#  (21, 2561, 207),
#  (22, 1000, 80),
#  (22, 383, 33),
#  (23, 1, 1),
#  (23, 6, 1),
#  (23, 7, 1),
#  (23, 8, 1),
#  (23, 9, 1),
#  (23, 10, 1),
#  (23, 11, 1),
#  (23, 12, 1),
#  (23, 13, 1),
#  (23, 14, 1),
#  (24, 1146, 90),
#  (24, 1147, 90),
#  (24, 1148, 90),
#  (24, 1149, 90),
#  (24, 1150, 90),
#  (24, 1151, 90),
#  (24, 1152, 90),
#  (24, 1153, 90),
#  (24, 1154, 90),
#  (24, 1155, 90),
#  (24, 1156, 90),
#  (24, 1157, 90),
#  (25, 46, 6),
#  (25, 948, 75),
#  (25, 2185, 180),
#  (25, 3049, 241),
#  (25, 1167, 91),
#  (25, 32, 5),
#  (25, 1800, 147),
#  (114, 1488, 120),
#  (114, 1489, 120),
#  (114, 1490, 120),
#  (114, 1491, 120),
#  (114, 1492, 120),
#  (114, 1493, 120),
#  (114, 1494, 120),
#  (114, 1495, 120),
#  (115, 298, 26),
#  (115, 2269, 185),
#  (115, 2610, 212),
#  (115, 1188, 93),
#  (115, 3370, 269),
#  (115, 2990, 237),
#  (115, 2684, 217),
#  (115, 1224, 96),
#  (115, 84, 9),
#  (116, 571, 46),
#  (116, 2739, 221),
#  (116, 1568, 126),
#  (116, 2975, 236),
#  (116, 1887, 155),
#  (116, 3092, 245),
#  (116, 35, 5),
#  (116, 66, 8),
#  (116, 1180, 92),
#  (116, 21, 4),
#  (116, 2254, 185),
#  (117, 4, 3),
#  (117, 3316, 258),
#  (117, 2558, 207),
#  (117, 2591, 211),
#  (117, 1880, 154),
#  (117, 831, 67),
#  (117, 1482, 120),
#  (117, 2174, 179),
#  (117, 3305, 258),
#  (117, 3365, 269),
#  (117, 614, 49),
#  (118, 3111, 246),
#  (119, 1556, 125),
#  (119, 2508, 203),
#  (120, 17, 4),
#  (120, 1126, 88),
#  (120, 2749, 221),
#  (120, 2596, 211),
#  (120, 2738, 221),
#  (120, 2350, 192),
#  (121, 2656, 215),
#  (121, 2549, 206),
#  (121, 1829, 150),
#  (121, 44, 6),
#  (121, 40, 6),
#  (121, 2674, 216),
#  (121, 3452, 318),
#  (121, 344, 30),
#  (121, 32, 5),
#  (122, 2014, 164),
#  (122, 28, 5),
#  (122, 42, 6),
#  (122, 839, 67),
#  (122, 1195, 93),
#  (123, 2003, 164),
#  (123, 2004, 164),
#  (123, 2005, 164),
#  (123, 2006, 164),
#  (123, 2007, 164),
#  (123, 2008, 164),
#  (123, 2009, 164),
#  (123, 2010, 164),
#  (123, 2011, 164),
#  (123, 2012, 164),
#  (123, 2013, 164),
#  (123, 2014, 164),
#  (124, 3100, 245),
#  (124, 3323, 259),
#  (124, 2328, 190),
#  (124, 470, 39),
#  (124, 1017, 81),
#  (124, 1816, 149),
#  ...]

# %% [markdown]
# From the above table we observe that if the tracks belonging to each distinct invoice, belongs to the same album it is an *Album Purchase*. If these tracks belong to different albums it is *Non Album Purchase*.
#
# Below we categorize these invoices into *Album and Non Album Purchase*. We do this by counting the number of distinct albums belonging to each invoice. Then we compare the *Distinct Albums* and *Number of Albums* belonging to each invoice.

# %%
# %%sql
# WITH com_pur AS
# (SELECT il.invoice_id invoice_id, il.track_id Pur_tracks, t.album_id album_id
#   FROM track t
# INNER JOIN invoice_line il ON il.track_id = t.track_id
# ORDER BY 1)
#
# SELECT invoice_id, COUNT(DISTINCT(album_id)) Distinct_album_id,
#        COUNT(album_id) No_of_album_id,
#        CASE
#        WHEN COUNT(album_id) - COUNT(DISTINCT(album_id)) <= 2 THEN "Non Album Purchase"
#        ELSE "Album Purchase"
#        END AS Category
#   FROM com_pur
# GROUP BY 1;
# Out:
# Done.
# [(1, 1, 16, 'Album Purchase'),
#  (2, 10, 10, 'Non Album Purchase'),
#  (3, 2, 2, 'Non Album Purchase'),
#  (4, 8, 8, 'Non Album Purchase'),
#  (5, 1, 17, 'Album Purchase'),
#  (6, 2, 2, 'Non Album Purchase'),
#  (7, 11, 11, 'Non Album Purchase'),
#  (8, 10, 10, 'Non Album Purchase'),
#  (9, 9, 9, 'Non Album Purchase'),
#  (10, 2, 2, 'Non Album Purchase'),
#  (11, 11, 11, 'Non Album Purchase'),
#  (12, 4, 4, 'Non Album Purchase'),
#  (13, 1, 1, 'Non Album Purchase'),
#  (14, 1, 1, 'Non Album Purchase'),
#  (15, 4, 4, 'Non Album Purchase'),
#  (16, 8, 9, 'Non Album Purchase'),
#  (17, 10, 11, 'Non Album Purchase'),
#  (18, 5, 5, 'Non Album Purchase'),
#  (19, 7, 7, 'Non Album Purchase'),
#  (20, 9, 10, 'Non Album Purchase'),
#  (21, 8, 9, 'Non Album Purchase'),
#  (22, 2, 2, 'Non Album Purchase'),
#  (23, 1, 10, 'Album Purchase'),
#  (24, 1, 12, 'Album Purchase'),
#  (25, 8, 8, 'Non Album Purchase'),
#  (26, 2, 2, 'Non Album Purchase'),
#  (27, 7, 8, 'Non Album Purchase'),
#  (28, 3, 3, 'Non Album Purchase'),
#  (29, 6, 6, 'Non Album Purchase'),
#  (30, 10, 11, 'Non Album Purchase'),
#  (31, 1, 20, 'Album Purchase'),
#  (32, 1, 13, 'Album Purchase'),
#  (33, 4, 4, 'Non Album Purchase'),
#  (34, 1, 1, 'Non Album Purchase'),
#  (35, 5, 5, 'Non Album Purchase'),
#  (36, 7, 7, 'Non Album Purchase'),
#  (37, 10, 10, 'Non Album Purchase'),
#  (38, 7, 7, 'Non Album Purchase'),
#  (39, 8, 8, 'Non Album Purchase'),
#  (40, 10, 10, 'Non Album Purchase'),
#  (41, 8, 8, 'Non Album Purchase'),
#  (42, 8, 9, 'Non Album Purchase'),
#  (43, 7, 7, 'Non Album Purchase'),
#  (44, 1, 12, 'Album Purchase'),
#  (45, 8, 8, 'Non Album Purchase'),
#  (46, 1, 11, 'Album Purchase'),
#  (47, 6, 6, 'Non Album Purchase'),
#  (48, 4, 4, 'Non Album Purchase'),
#  (49, 4, 5, 'Non Album Purchase'),
#  (50, 7, 7, 'Non Album Purchase'),
#  (51, 8, 8, 'Non Album Purchase'),
#  (52, 1, 12, 'Album Purchase'),
#  (53, 3, 3, 'Non Album Purchase'),
#  (54, 1, 18, 'Album Purchase'),
#  (55, 9, 10, 'Non Album Purchase'),
#  (56, 1, 17, 'Album Purchase'),
#  (57, 1, 1, 'Non Album Purchase'),
#  (58, 6, 6, 'Non Album Purchase'),
#  (59, 11, 11, 'Non Album Purchase'),
#  (60, 8, 8, 'Non Album Purchase'),
#  (61, 1, 12, 'Album Purchase'),
#  (62, 3, 3, 'Non Album Purchase'),
#  (63, 5, 6, 'Non Album Purchase'),
#  (64, 1, 13, 'Album Purchase'),
#  (65, 2, 2, 'Non Album Purchase'),
#  (66, 7, 7, 'Non Album Purchase'),
#  (67, 11, 11, 'Non Album Purchase'),
#  (68, 11, 11, 'Non Album Purchase'),
#  (69, 1, 14, 'Album Purchase'),
#  (70, 1, 1, 'Non Album Purchase'),
#  (71, 1, 17, 'Album Purchase'),
#  (270, 11, 11, 'Non Album Purchase'),
#  (271, 1, 11, 'Album Purchase'),
#  (272, 8, 9, 'Non Album Purchase'),
#  (273, 1, 17, 'Album Purchase'),
#  (274, 5, 5, 'Non Album Purchase'),
#  (275, 8, 8, 'Non Album Purchase'),
#  (276, 1, 19, 'Album Purchase'),
#  (277, 5, 5, 'Non Album Purchase'),
#  (278, 3, 3, 'Non Album Purchase'),
#  (279, 5, 5, 'Non Album Purchase'),
#  (280, 1, 11, 'Album Purchase'),
#  (281, 1, 14, 'Album Purchase'),
#  (282, 1, 17, 'Album Purchase'),
#  (283, 9, 9, 'Non Album Purchase'),
#  (284, 1, 11, 'Album Purchase'),
#  (285, 10, 10, 'Non Album Purchase'),
#  (286, 2, 2, 'Non Album Purchase'),
#  (287, 2, 2, 'Non Album Purchase'),
#  (288, 10, 11, 'Non Album Purchase'),
#  (289, 7, 7, 'Non Album Purchase'),
#  (290, 5, 5, 'Non Album Purchase'),
#  (291, 3, 3, 'Non Album Purchase'),
#  (292, 10, 10, 'Non Album Purchase'),
#  (293, 5, 5, 'Non Album Purchase'),
#  (294, 11, 11, 'Non Album Purchase'),
#  (295, 1, 1, 'Non Album Purchase'),
#  (296, 1, 13, 'Album Purchase'),
#  (297, 3, 3, 'Non Album Purchase'),
#  (298, 9, 9, 'Non Album Purchase'),
#  (299, 6, 6, 'Non Album Purchase'),
#  (300, 1, 12, 'Album Purchase'),
#  (301, 8, 8, 'Non Album Purchase'),
#  (302, 4, 4, 'Non Album Purchase'),
#  (303, 10, 10, 'Non Album Purchase'),
#  (304, 7, 7, 'Non Album Purchase'),
#  (305, 1, 15, 'Album Purchase'),
#  (306, 10, 11, 'Non Album Purchase'),
#  (307, 10, 10, 'Non Album Purchase'),
#  (308, 1, 11, 'Album Purchase'),
#  (309, 8, 9, 'Non Album Purchase'),
#  (310, 9, 9, 'Non Album Purchase'),
#  (311, 6, 6, 'Non Album Purchase'),
#  (312, 10, 10, 'Non Album Purchase'),
#  (313, 5, 5, 'Non Album Purchase'),
#  (314, 10, 10, 'Non Album Purchase'),
#  (315, 5, 5, 'Non Album Purchase'),
#  (316, 2, 2, 'Non Album Purchase'),
#  (317, 1, 12, 'Album Purchase'),
#  (318, 8, 8, 'Non Album Purchase'),
#  (319, 9, 10, 'Non Album Purchase'),
#  (320, 1, 17, 'Album Purchase'),
#  (321, 1, 1, 'Non Album Purchase'),
#  (322, 9, 10, 'Non Album Purchase'),
#  (323, 8, 8, 'Non Album Purchase'),
#  (324, 5, 5, 'Non Album Purchase'),
#  (325, 9, 10, 'Non Album Purchase'),
#  (326, 9, 9, 'Non Album Purchase'),
#  (327, 9, 9, 'Non Album Purchase'),
#  (328, 4, 4, 'Non Album Purchase'),
#  (329, 1, 1, 'Non Album Purchase'),
#  (330, 1, 13, 'Album Purchase'),
#  (331, 6, 6, 'Non Album Purchase'),
#  (332, 9, 10, 'Non Album Purchase'),
#  (333, 6, 6, 'Non Album Purchase'),
#  (334, 1, 15, 'Album Purchase'),
#  (335, 1, 15, 'Album Purchase'),
#  (336, 1, 16, 'Album Purchase'),
#  (337, 9, 10, 'Non Album Purchase'),
#  (338, 5, 5, 'Non Album Purchase'),
#  (339, 8, 8, 'Non Album Purchase'),
#  (340, 3, 3, 'Non Album Purchase'),
#  (341, 1, 12, 'Album Purchase'),
#  (342, 3, 3, 'Non Album Purchase'),
#  (343, 6, 6, 'Non Album Purchase'),
#  (344, 1, 17, 'Album Purchase'),
#  (345, 10, 10, 'Non Album Purchase'),
#  (346, 6, 6, 'Non Album Purchase'),
#  (347, 4, 4, 'Non Album Purchase'),
#  (348, 9, 9, 'Non Album Purchase'),
#  (349, 1, 1, 'Non Album Purchase'),
#  (350, 3, 3, 'Non Album Purchase'),
#  (351, 9, 10, 'Non Album Purchase'),
#  (352, 1, 1, 'Non Album Purchase'),
#  (353, 8, 10, 'Non Album Purchase'),
#  (354, 5, 5, 'Non Album Purchase'),
#  (355, 7, 7, 'Non Album Purchase'),
#  (356, 7, 7, 'Non Album Purchase'),
#  (357, 3, 3, 'Non Album Purchase'),
#  (358, 6, 7, 'Non Album Purchase'),
#  (359, 9, 9, 'Non Album Purchase'),
#  (360, 4, 4, 'Non Album Purchase'),
#  (361, 2, 2, 'Non Album Purchase'),
#  (362, 1, 20, 'Album Purchase'),
#  (363, 3, 3, 'Non Album Purchase'),
#  (364, 6, 6, 'Non Album Purchase'),
#  (365, 4, 4, 'Non Album Purchase'),
#  (366, 9, 9, 'Non Album Purchase'),
#  (367, 7, 8, 'Non Album Purchase'),
#  (368, 2, 2, 'Non Album Purchase'),
#  (369, 10, 10, 'Non Album Purchase'),
#  (370, 9, 9, 'Non Album Purchase'),
#  (371, 1, 1, 'Non Album Purchase'),
#  (372, 1, 14, 'Album Purchase'),
#  (373, 4, 4, 'Non Album Purchase'),
#  (374, 6, 6, 'Non Album Purchase'),
#  (375, 1, 9, 'Album Purchase'),
#  (376, 4, 4, 'Non Album Purchase'),
#  (377, 3, 3, 'Non Album Purchase'),
#  (378, 4, 4, 'Non Album Purchase'),
#  (379, 1, 12, 'Album Purchase'),
#  (380, 10, 10, 'Non Album Purchase'),
#  (381, 1, 13, 'Album Purchase'),
#  (382, 4, 4, 'Non Album Purchase'),
#  (383, 10, 10, 'Non Album Purchase'),
#  (384, 10, 11, 'Non Album Purchase'),
#  (385, 6, 7, 'Non Album Purchase'),
#  (386, 5, 5, 'Non Album Purchase'),
#  (387, 6, 6, 'Non Album Purchase'),
#  (388, 1, 10, 'Album Purchase'),
#  (389, 1, 17, 'Album Purchase'),
#  (390, 3, 3, 'Non Album Purchase'),
#  (391, 3, 4, 'Non Album Purchase'),
#  (392, 1, 8, 'Album Purchase'),
#  (393, 10, 11, 'Non Album Purchase'),
#  (394, 7, 8, 'Non Album Purchase'),
#  (395, 10, 10, 'Non Album Purchase'),
#  (396, 9, 9, 'Non Album Purchase'),
#  (397, 6, 7, 'Non Album Purchase'),
#  (398, 1, 17, 'Album Purchase'),
#  (399, 1, 12, 'Album Purchase'),
#  (400, 4, 4, 'Non Album Purchase'),
#  (401, 9, 10, 'Non Album Purchase'),
#  (468, 1, 16, 'Album Purchase'),
#  (469, 1, 1, 'Non Album Purchase'),
#  (470, 2, 2, 'Non Album Purchase'),
#  (471, 1, 1, 'Non Album Purchase'),
#  (472, 3, 3, 'Non Album Purchase'),
#  (473, 3, 4, 'Non Album Purchase'),
#  (474, 7, 7, 'Non Album Purchase'),
#  (475, 8, 8, 'Non Album Purchase'),
#  (476, 11, 11, 'Non Album Purchase'),
#  (477, 7, 7, 'Non Album Purchase'),
#  (478, 1, 17, 'Album Purchase'),
#  (479, 1, 17, 'Album Purchase'),
#  (480, 10, 10, 'Non Album Purchase'),
#  (481, 4, 4, 'Non Album Purchase'),
#  (482, 8, 8, 'Non Album Purchase'),
#  (483, 5, 5, 'Non Album Purchase'),
#  (484, 3, 3, 'Non Album Purchase'),
#  (485, 1, 10, 'Album Purchase'),
#  (486, 8, 9, 'Non Album Purchase'),
#  (487, 10, 10, 'Non Album Purchase'),
#  (488, 1, 14, 'Album Purchase'),
#  (489, 3, 3, 'Non Album Purchase'),
#  (490, 9, 9, 'Non Album Purchase'),
#  (491, 2, 2, 'Non Album Purchase'),
#  (492, 5, 5, 'Non Album Purchase'),
#  (493, 4, 4, 'Non Album Purchase'),
#  (494, 1, 10, 'Album Purchase'),
#  (495, 1, 1, 'Non Album Purchase'),
#  (496, 1, 8, 'Album Purchase'),
#  (497, 7, 7, 'Non Album Purchase'),
#  (498, 4, 4, 'Non Album Purchase'),
#  (499, 1, 10, 'Album Purchase'),
#  (500, 9, 9, 'Non Album Purchase'),
#  (501, 1, 13, 'Album Purchase'),
#  (502, 4, 4, 'Non Album Purchase'),
#  (503, 10, 10, 'Non Album Purchase'),
#  (504, 11, 11, 'Non Album Purchase'),
#  (505, 1, 1, 'Non Album Purchase'),
#  (506, 1, 16, 'Album Purchase'),
#  (507, 1, 1, 'Non Album Purchase'),
#  (508, 9, 9, 'Non Album Purchase'),
#  (509, 6, 7, 'Non Album Purchase'),
#  (510, 1, 10, 'Album Purchase'),
#  (511, 1, 7, 'Album Purchase'),
#  (512, 1, 9, 'Album Purchase'),
#  (513, 11, 11, 'Non Album Purchase'),
#  (514, 3, 3, 'Non Album Purchase'),
#  (515, 3, 3, 'Non Album Purchase'),
#  (516, 2, 2, 'Non Album Purchase'),
#  (517, 7, 9, 'Non Album Purchase'),
#  (518, 2, 2, 'Non Album Purchase'),
#  (519, 7, 7, 'Non Album Purchase'),
#  (520, 7, 10, 'Album Purchase'),
#  (521, 4, 4, 'Non Album Purchase'),
#  (522, 8, 8, 'Non Album Purchase'),
#  (523, 7, 8, 'Non Album Purchase'),
#  (524, 5, 5, 'Non Album Purchase'),
#  (525, 9, 10, 'Non Album Purchase'),
#  (526, 1, 20, 'Album Purchase'),
#  (527, 11, 11, 'Non Album Purchase'),
#  (528, 1, 16, 'Album Purchase'),
#  (529, 1, 14, 'Album Purchase'),
#  (530, 1, 1, 'Non Album Purchase'),
#  (531, 1, 12, 'Album Purchase'),
#  (532, 1, 14, 'Album Purchase'),
#  (533, 1, 13, 'Album Purchase'),
#  (534, 6, 6, 'Non Album Purchase'),
#  (535, 1, 1, 'Non Album Purchase'),
#  (536, 6, 6, 'Non Album Purchase'),
#  (537, 1, 8, 'Album Purchase'),
#  (538, 9, 9, 'Non Album Purchase'),
#  (539, 1, 1, 'Non Album Purchase'),
#  (540, 1, 11, 'Album Purchase'),
#  (541, 3, 3, 'Non Album Purchase'),
#  (542, 1, 11, 'Album Purchase'),
#  (543, 3, 3, 'Non Album Purchase'),
#  (544, 9, 9, 'Non Album Purchase'),
#  (545, 8, 8, 'Non Album Purchase'),
#  (546, 7, 7, 'Non Album Purchase'),
#  (547, 10, 10, 'Non Album Purchase'),
#  (548, 11, 11, 'Non Album Purchase'),
#  (549, 11, 11, 'Non Album Purchase'),
#  (550, 1, 10, 'Album Purchase'),
#  (551, 1, 11, 'Album Purchase'),
#  (552, 5, 6, 'Non Album Purchase'),
#  (553, 5, 5, 'Non Album Purchase'),
#  (554, 9, 9, 'Non Album Purchase'),
#  (555, 2, 2, 'Non Album Purchase'),
#  (556, 1, 11, 'Album Purchase'),
#  (557, 10, 10, 'Non Album Purchase'),
#  (558, 11, 11, 'Non Album Purchase'),
#  (559, 6, 6, 'Non Album Purchase'),
#  (560, 9, 9, 'Non Album Purchase'),
#  (561, 7, 7, 'Non Album Purchase'),
#  (562, 9, 9, 'Non Album Purchase'),
#  (563, 2, 2, 'Non Album Purchase'),
#  (564, 6, 6, 'Non Album Purchase'),
#  (565, 10, 10, 'Non Album Purchase'),
#  (566, 5, 5, 'Non Album Purchase'),
#  (567, 8, 8, 'Non Album Purchase'),
#  (568, 7, 7, 'Non Album Purchase'),
#  (569, 1, 1, 'Non Album Purchase'),
#  (570, 3, 3, 'Non Album Purchase'),
#  (571, 3, 3, 'Non Album Purchase'),
#  (572, 5, 5, 'Non Album Purchase'),
#  (573, 9, 11, 'Non Album Purchase'),
#  (574, 11, 11, 'Non Album Purchase'),
#  (575, 4, 4, 'Non Album Purchase'),
#  (576, 6, 6, 'Non Album Purchase'),
#  (577, 9, 9, 'Non Album Purchase'),
#  (578, 1, 12, 'Album Purchase'),
#  (579, 11, 11, 'Non Album Purchase'),
#  (580, 10, 10, 'Non Album Purchase'),
#  (581, 1, 14, 'Album Purchase'),
#  (582, 1, 18, 'Album Purchase'),
#  (583, 1, 11, 'Album Purchase'),
#  (584, 1, 1, 'Non Album Purchase'),
#  (585, 9, 9, 'Non Album Purchase'),
#  (586, 11, 11, 'Non Album Purchase'),
#  (587, 2, 2, 'Non Album Purchase'),
#  (588, 1, 1, 'Non Album Purchase'),
#  (589, 1, 11, 'Album Purchase'),
#  (590, 1, 9, 'Album Purchase'),
#  (591, 7, 7, 'Non Album Purchase'),
#  (592, 8, 8, 'Non Album Purchase'),
#  (593, 10, 11, 'Non Album Purchase'),
#  (594, 3, 3, 'Non Album Purchase'),
#  (595, 8, 8, 'Non Album Purchase'),
#  (596, 6, 6, 'Non Album Purchase'),
#  (597, 6, 7, 'Non Album Purchase'),
#  (598, 5, 5, 'Non Album Purchase'),
#  (599, 8, 8, 'Non Album Purchase'),
#  (600, 5, 5, 'Non Album Purchase'),
#  (601, 11, 11, 'Non Album Purchase'),
#  (602, 7, 7, 'Non Album Purchase'),
#  (603, 5, 5, 'Non Album Purchase'),
#  (604, 1, 18, 'Album Purchase'),
#  (605, 4, 4, 'Non Album Purchase'),
#  (606, 1, 12, 'Album Purchase'),
#  (607, 5, 5, 'Non Album Purchase'),
#  (608, 1, 1, 'Non Album Purchase'),
#  (609, 3, 3, 'Non Album Purchase'),
#  (610, 7, 7, 'Non Album Purchase'),
#  (611, 2, 2, 'Non Album Purchase'),
#  (612, 1, 12, 'Album Purchase'),
#  (613, 8, 9, 'Non Album Purchase'),
#  (614, 1, 13, 'Album Purchase')]

# %% [markdown]
# ### 5.1 Category: Not an Album Purchase

# %% [markdown]
# Here we calculate the *Percentage of Non Album Purchases* for the company.

# %%
# %%sql
# WITH com_pur AS
# (SELECT il.invoice_id invoice_id, il.track_id Pur_tracks, t.album_id album_id
#   FROM track t
# INNER JOIN invoice_line il ON il.track_id = t.track_id
# ORDER BY 1),
#
# ctgr_pur AS
# (SELECT invoice_id, COUNT(DISTINCT(album_id)) Distinct_album_id,
#        COUNT(album_id) No_of_album_id,
#        CASE
#        WHEN COUNT(album_id) - COUNT(DISTINCT(album_id)) <= 2 THEN "Non Album Purchase"
#        ELSE "Album Purchase"
#        END AS Category
#   FROM com_pur
# GROUP BY 1)
#
# SELECT (SELECT MAX(invoice_id)
#           FROM invoice_line) TOTAL_invoice_id,
#        COUNT(invoice_id) No_of_invoice_id,
#        (SELECT ROUND(CAST(COUNT(invoice_id) AS FLOAT) * 100 / (SELECT MAX(invoice_id)
#                                             FROM invoice_line), 2)) Perc_invoice
#   FROM ctgr_pur
# WHERE Category = "Non Album Purchase";
# Out:
# Done.
# [(614, 480, 78.18)]

# %% [markdown]
# From the above table we deduce that out of *614* invoices, *480* invoices are *Non Album Purchases*. i.e. *~ 78%* of purchases are *Non Album Purchases*.

# %% [markdown]
# ### 5.2 Category: Album Purchase

# %% [markdown]
# Here we calculate the *Percentage of Album Purchase* for the company.

# %%
# %%sql
#
# WITH com_pur AS
# (SELECT il.invoice_id invoice_id, il.track_id Pur_tracks, t.album_id album_id
#   FROM track t
# INNER JOIN invoice_line il ON il.track_id = t.track_id
# ORDER BY 1),
#
# ctgr_pur AS
# (SELECT invoice_id, COUNT(DISTINCT(album_id)) Distinct_album_id,
#        COUNT(album_id) No_of_album_id,
#        CASE
#        WHEN COUNT(album_id) - COUNT(DISTINCT(album_id)) <= 2 THEN "Non Album Purchase"
#        ELSE "Album Purchase"
#        END AS Category
#   FROM com_pur
# GROUP BY 1)
#
#
# SELECT (SELECT MAX(invoice_id)
#   FROM invoice_line) TOTAL_invoice_id,
#        COUNT(invoice_id) No_of_invoice_id,
#       (SELECT ROUND(CAST(COUNT(invoice_id) AS FLOAT) * 100 / (SELECT MAX(invoice_id)
#                                            FROM invoice_line), 2)) Perc_invoice
#  FROM ctgr_pur
# WHERE Category = "Album Purchase";
# Out:
# Done.
# [(614, 134, 21.82)]

# %% [markdown]
# From the above table we deduce that out of *614* invoices, only *134* are *Ablum Purchases*. i.e. *~ 22%* of total purchases is an *Album Purchase*.

# %% [markdown]
# From the analysis it is clear that the individual track purchases (~ 78%) is comapartively higher than album purchases (~ 22%).  And we infer that the store should consider buying popular tracks from albums rather than buying the whole album from record companies.

# %% [markdown]
# ## 6. Extra Queries

# %% [markdown]
# ### 6.1. Artist Used in Most Playlists

# %% [markdown]
# In this querry we are going to find out *which artist is used in most playlists*. For this analysis we first join *playlist table* and *artist table* using *INNER JOIN* method. Then we will use *GROUP BY* method on *artists* and count the number of *playlists*. The artist with maximum number of playlists is in most playlists.

# %%
# %%sql
# WITH pl_ar AS
# (SELECT p.name playlists, at.name artists
#    FROM playlist p
#  INNER JOIN playlist_track pt ON pt.playlist_id = p.playlist_id
#  INNER JOIN track t ON t.track_id = pt.track_id
#  INNER JOIN album a ON a.album_id = t.album_id
#  INNER JOIN artist at ON at.artist_id = a.album_id)
#
# SELECT playlists, artists, COUNT(*) No_of_playlists
#   FROM pl_ar
# GROUP BY 2
# ORDER BY 3 DESC;
# Out:
# Done.
# [('Music', 'The Police', 143),
#  ('Brazilian Music', 'Vinícius E Qurteto Em Cy', 91),
#  ('Brazilian Music', 'Frank Zappa & Captain Beefheart', 87),
#  ('Music', 'Marcos Valle', 69),
#  ('Music', 'Barry Wordsworth & BBC Concert Orchestra', 66),
#  ('Music', 'Big & Rich', 63),
#  ('Music', 'Page & Plant', 60),
#  ('Music', 'Ed Motta', 59),
#  ('Music', 'Berliner Philharmoniker & Herbert Von Karajan', 57),
#  ('Music', 'Fernanda Porto', 57),
#  ('Music', 'Les Arts Florissants & William Christie', 57),
#  ('Brazilian Music', 'Various Artists', 57),
#  ('Music', 'Vinícius De Moraes', 54),
#  ('Music', 'Wilhelm Kempff', 54),
#  ('TV Shows', 'Boston Symphony Orchestra & Seiji Ozawa', 52),
#  ('Heavy Metal Classic', 'Los Lonely Boys', 52),
#  ('Music', 'Chico Science & Nação Zumbi', 51),
#  ('Music', 'Corinne Bailey Rae', 51),
#  ('Music', 'Seu Jorge', 51),
#  ('TV Shows', 'Aaron Copland & London Symphony Orchestra', 50),
#  ('Music', 'Aaron Goldberg', 50),
#  ('TV Shows', 'Fretwork', 50),
#  ('Grunge', 'Nicolaus Esterhazy Sinfonia', 49),
#  ('TV Shows', 'Calexico', 48),
#  ('Music', 'Falamansa', 48),
#  ('Music', 'Foo Fighters', 48),
#  ('Brazilian Music', 'Funk Como Le Gusta', 48),
#  ('Music', 'Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 48),
#  ('Music', 'James Brown', 48),
#  ('Music', 'Lost', 48),
#  ('Music', 'Regina Spektor', 48),
#  ('Music', 'Rodox', 48),
#  ('Music', 'Santana Feat. Eric Clapton', 48),
#  ('Music', 'The Doors', 48),
#  ('TV Shows', 'Ton Koopman', 48),
#  ('TV Shows', 'Leonard Bernstein & New York Philharmonic', 46),
#  ('Music', 'Yehudi Menuhin', 46),
#  ('Music', 'Alice In Chains', 45),
#  ('Music', 'Creedence Clearwater Revival', 45),
#  ('Music', 'Orchestra of The Age of Enlightenment', 45),
#  ('Music', 'Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 45),
#  ('Music', 'Raul Seixas', 45),
#  ('Music', 'Stereo Maracana', 45),
#  ('Music', 'The Cult', 45),
#  ('TV Shows', "Christopher O'Riley", 44),
#  ('Brazilian Music', 'Elis Regina', 44),
#  ('Music', 'Queen', 44),
#  ('Music', 'Britten Sinfonia, Ivor Bolton & Lesley Garrett', 43),
#  ('Music', 'Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 42),
#  ('Music', 'Cake', 42),
#  ('Grunge', 'Dhani Harrison & Jakob Dylan', 42),
#  ('Music', 'Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 42),
#  ('Music', 'Gilberto Gil', 42),
#  ('Music', 'Hermeto Pascoal', 42),
#  ('Music', 'Jamiroquai', 42),
#  ('Music', 'Jorge Vercilo', 42),
#  ('Music', 'Maurizio Pollini', 42),
#  ('Music', 'Otto', 42),
#  ('Music', 'Royal Philharmonic Orchestra & Sir Thomas Beecham', 42),
#  ('Music', 'The Flaming Lips', 42),
#  ('Brazilian Music', 'Toquinho & Vinícius', 42),
#  ('Music', 'UB40', 42),
#  ('Music', 'Vinicius, Toquinho & Quarteto Em Cy', 42),
#  ('Brazilian Music', 'Gene Krupa', 41),
#  ('Music', 'Antal Doráti & London Symphony Orchestra', 40),
#  ('Music', 'David Coverdale', 40),
#  ('Music', 'Green Day', 40),
#  ('Music', 'Scholars Baroque Ensemble', 40),
#  ('Music', 'Sir Georg Solti & Wiener Philharmoniker', 40),
#  ('Music', 'Antônio Carlos Jobim', 39),
#  ('Music', 'Faith No More', 39),
#  ('Music', 'JET', 39),
#  ('Music', 'Jorge Ben', 39),
#  ('Music', 'Milton Nascimento & Bebeto', 39),
#  ('Music', 'Velvet Revolver', 39),
#  ('TV Shows', 'Luciano Pavarotti', 38),
#  ('Music', 'O Rappa', 38),
#  ('Grunge', 'Alberto Turco & Nova Schola Gregoriana', 37),
#  ('Grunge', 'Apocalyptica', 37),
#  ('Heavy Metal Classic', 'Heroes', 37),
#  ('Grunge', 'Nega Gizza', 37),
#  ('Music', 'Banda Black Rio', 36),
#  ('Music', 'Black Sabbath', 36),
#  ('Music', 'Jaguares', 36),
#  ('Music', 'James Levine', 36),
#  ('Music', 'Joe Satriani', 36),
#  ('Music', 'Legião Urbana', 36),
#  ('Music', 'Marillion', 36),
#  ('Music', 'Michael Tilson Thomas & San Francisco Symphony', 36),
#  ('Brazilian Music', 'Nando Reis', 36),
#  ('Music', 'Philharmonia Orchestra & Sir Neville Marriner', 36),
#  ('Music', 'R.E.M. Feat. KRS-One', 36),
#  ('Music', 'Santana Feat. Lauryn Hill & Cee-Lo', 36),
#  ('Music', 'Sergei Prokofiev & Yuri Temirkanov', 36),
#  ('Music', 'Tim Maia', 36),
#  ('Music', 'Titãs', 36),
#  ('Music', 'Vinícius E Odette Lara', 36),
#  ('Grunge', 'Xis', 36),
#  ('Music', 'Luciana Souza/Romero Lubambo', 35),
#  ('Brazilian Music', 'Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 34),
#  ('Music', 'Azymuth', 34),
#  ('Music', 'Berliner Philharmoniker & Hans Rosbaud', 34),
#  ('Music', 'Charlie Brown Jr.', 34),
#  ('Music', 'Luiz Melodia', 34),
#  ('Music', 'Pink Floyd', 34),
#  ('TV Shows', 'Roger Norrington, London Classical Players', 34),
#  ('Music', 'The 12 Cellists of The Berlin Philharmonic', 34),
#  ('Music', 'Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 33),
#  ('Music', 'Cidade Negra', 33),
#  ('Music', 'Def Leppard', 33),
#  ('Music', 'Jota Quest', 33),
#  ('Brazilian Music', 'London Symphony Orchestra & Sir Charles Mackerras', 33),
#  ('Music', 'Los Hermanos', 33),
#  ('Music', 'Os Paralamas Do Sucesso', 33),
#  ('Music', "Paul D'Ianno", 33),
#  ('Music', 'Pearl Jam', 33),
#  ('Music', 'Pedro Luís & A Parede', 33),
#  ('Music', 'Raimundos', 33),
#  ('Music', 'Santana Feat. Everlast', 33),
#  ('Music', 'The Posies', 33),
#  ('Music', 'Black Eyed Peas', 32),
#  ('Heavy Metal Classic', 'Christina Aguilera featuring BigElf', 32),
#  ('Music', 'Instituto', 32),
#  ('Brazilian Music', 'Os Mutantes', 32),
#  ('Music', 'Sabotage E Instituto', 32),
#  ('Grunge', 'Michele Campanella', 31),
#  ('Brazilian Music', 'R.E.M. Feat. Kate Pearson', 31),
#  ('Brazilian Music', 'Vinícius De Moraes & Baden Powell', 31),
#  ('Music', 'Gonzaguinha', 30),
#  ('Music', 'Gustav Mahler', 30),
#  ('Music', 'House Of Pain', 30),
#  ('Music', 'Jackson Browne', 30),
#  ('Music', 'Kiss', 30),
#  ('Music', 'Marisa Monte', 30),
#  ('Music', 'Marvin Gaye', 30),
#  ('Music', 'Men At Work', 30),
#  ('Music', 'Nação Zumbi', 30),
#  ('Music', 'Passengers', 30),
#  ('Music', 'Planet Hemp', 30),
#  ('Music', 'Red Hot Chili Peppers', 30),
#  ('Music', 'Santana Feat. Eagle-Eye Cherry', 30),
#  ('Music', "The King's Singers", 30),
#  ('Brazilian Music', 'Battlestar Galactica (Classic)', 29),
#  ('Music Videos', 'Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 29),
#  ('Music', 'Audioslave', 28),
#  ('Music', 'Avril Lavigne', 28),
#  ('Music', 'Bebel Gilberto', 28),
#  ('Music', 'Billy Cobham', 28),
#  ('Music', 'DJ Dolores & Orchestra Santa Massa', 28),
#  ('Music', 'Dread Zeppelin', 28),
#  ('Music', 'Frank Sinatra', 28),
#  ('Music', 'Gerald Moore', 28),
#  ('Music', 'Milton Nascimento', 28),
#  ('Music', 'Ney Matogrosso', 28),
#  ('Music', 'R.E.M.', 28),
#  ('Music', 'Sandra De Sá', 28),
#  ('Music', 'Spyro Gyra', 28),
#  ('Music', 'The Postal Service', 28),
#  ('Music', 'The Rolling Stones', 28),
#  ('Music', 'The Tea Party', 28),
#  ('On-The-Go 1', 'Barão Vermelho', 27),
#  ('Music', 'Santana Feat. The Project G&B', 27),
#  ('Music', 'Aquaman', 26),
#  ('Music', 'Bruce Dickinson', 26),
#  ('Music', 'Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 26),
#  ('Music', 'Incognito', 26),
#  ('Music', 'Peter Tosh', 26),
#  ('Music', 'Scorpions', 26),
#  ('Heavy Metal Classic', 'Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 25),
#  ('Music', "Aerosmith & Sierra Leone's Refugee Allstars", 24),
#  ('Music', 'Aisha Duo', 24),
#  ('Music', 'BackBeat', 24),
#  ('Music', 'Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 24),
#  ('Music', 'Black Label Society', 24),
#  ('Music', 'Edo de Waart & San Francisco Symphony', 24),
#  ('Music', "Guns N' Roses", 24),
#  ('Music', 'Iron Maiden', 24),
#  ('Music', 'Karsh Kale', 24),
#  ('Music', 'Os Cariocas', 24),
#  ('Music', 'Ozzy Osbourne', 24),
#  ('Music', 'Yo-Yo Ma', 24),
#  ('Music', "Youssou N'Dour", 24),
#  ('Music', 'Academy of St. Martin in the Fields & Sir Neville Marriner', 22),
#  ('Music', 'Chicago Symphony Orchestra & Fritz Reiner', 22),
#  ('Music', 'Choir Of Westminster Abbey & Simon Preston', 22),
#  ('Music', 'Cláudio Zoli', 22),
#  ('Music', 'Cássia Eller', 22),
#  ('Music', 'Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 22),
#  ('Music', 'Eric Clapton', 22),
#  ('Music', 'Jimi Hendrix', 22),
#  ('Music', 'Judas Priest', 22),
#  ('Heavy Metal Classic', 'Lulu Santos', 22),
#  ('Music', 'Mundo Livre S/A', 22),
#  ('Music', 'Pedro Luís E A Parede', 22),
#  ('Music', 'Richard Marlow & The Choir of Trinity College, Cambridge', 22),
#  ('Heavy Metal Classic', 'U2', 22),
#  ('Music', 'Zeca Pagodinho', 22),
#  ('Heavy Metal Classic', 'AC/DC', 21),
#  ('Heavy Metal Classic', 'Chico Buarque', 21),
#  ('Music', 'English Concert & Trevor Pinnock', 21),
#  ('Music', 'Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', 20),
#  ('Music', 'Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 20),
#  ('Music', 'Battlestar Galactica', 20),
#  ('Music', 'Chris Cornell', 20),
#  ('Music', 'Dennis Chambers', 20),
#  ('Music', 'Djavan', 20),
#  ('Music', 'Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', 20),
#  ('Music', "Jack's Mannequin & Mick Fleetwood", 20),
#  ('Music', 'João Gilberto', 20),
#  ('Music', 'João Suplicy', 20),
#  ('Music', 'Mônica Marianno', 20),
#  ('Music', 'Stone Temple Pilots', 20),
#  ('Music', 'The Who', 20),
#  ('Heavy Metal Classic', 'Motörhead', 19),
#  ('Music', 'Baby Consuelo', 18),
#  ('Music', 'Deep Purple', 18),
#  ('Music', 'Gustavo & Andres Veiga & Salazar', 18),
#  ('Music', 'Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 18),
#  ('Music', 'Lenny Kravitz', 18),
#  ('Music', 'Miles Davis', 18),
#  ('Music', 'Mötley Crüe', 18),
#  ('Music', 'Santana Feat. Maná', 18),
#  ('Music', 'Soundgarden', 18),
#  ('Music', 'Stevie Ray Vaughan & Double Trouble', 18),
#  ('Music', 'System Of A Down', 18),
#  ('Music', 'Temple of the Dog', 18),
#  ('Music', 'The Office', 18),
#  ('Heavy Metal Classic', 'Whitesnake', 18),
#  ('Heavy Metal Classic', 'Motörhead & Girlschool', 17),
#  ('Heavy Metal Classic', 'O Terço', 17),
#  ('Heavy Metal Classic', 'Olodum', 17),
#  ('Heavy Metal Classic', 'Van Halen', 17),
#  ('Music', 'Alanis Morissette', 16),
#  ('Music', 'Body Count', 16),
#  ('Music', 'Nirvana', 16),
#  ('Music', 'Rush', 16),
#  ('Music', 'Simply Red', 16),
#  ('Music', 'Smashing Pumpkins', 16),
#  ('Heavy Metal Classic', 'Caetano Veloso', 15),
#  ('Music', 'A Cor Do Som', 14),
#  ('Music', 'Santana', 14),
#  ('Music', 'Santana Feat. Dave Matthews', 14),
#  ('Music', 'Santana Feat. Rob Thomas', 14),
#  ('Music', 'Skank', 14),
#  ('Music', 'Terry Bozzio, Tony Levin & Steve Stevens', 14),
#  ('Heavy Metal Classic', 'Aerosmith', 12),
#  ('Music', 'Habib Koité and Bamada', 12),
#  ('Music', 'Kid Abelha', 12),
#  ('TV Shows', 'Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 12),
#  ('Music', 'Buddy Guy', 10),
#  ('Music', 'The Black Crowes', 10),
#  ('Music', 'Metallica', 8),
#  ('Music', 'The Clash', 8),
#  ('Heavy Metal Classic', 'Ben Harper', 6),
#  ('Music', 'Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 6),
#  ('Music', 'Godsmack', 6),
#  ('Music', 'Led Zeppelin', 6),
#  ('Classical 101 - The Basics', 'C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 5),
#  ('Classical 101 - The Basics', 'Emerson String Quartet', 5),
#  ('Music', "Charles Dutoit & L'Orchestre Symphonique de Montréal", 4),
#  ('Music', 'Julian Bream', 4),
#  ('Music', "Kent Nagano and Orchestre de l'Opéra de Lyon", 4),
#  ('Music', 'Matisyahu', 4),
#  ('Classical 101 - The Basics', 'Nash Ensemble', 4),
#  ('Classical 101 - The Basics', 'Philip Glass Ensemble', 4),
#  ('Heavy Metal Classic', 'Accept', 3),
#  ('Music', 'Amy Winehouse', 3),
#  ('Music', 'Itzhak Perlman', 3),
#  ('Heavy Metal Classic', 'Snow Patrol', 3),
#  ('Music', 'Adrian Leaper & Doreen de Feis', 2),
#  ('TV Shows', 'Eugene Ormandy', 2),
#  ('Music', 'Göteborgs Symfoniker & Neeme Järvi', 2),
#  ('Music', 'Jack Johnson', 2),
#  ('Music', 'Martin Roscoe', 2),
#  ('TV Shows', 'Otto Klemperer & Philharmonia Orchestra', 2)]

# %% [markdown]
# From the above table we can conclude that **The Police** with *143* numbers is used in most playlists.

# %% [markdown]
# ### 6.2. Tracks Purchased Vs Not Purchased

# %% [markdown]
# In this section we are going to calculate the *number of tracks purchased* Vs *number of tracks not purchased*. First let us calculate how many tracks are there with the *Chinook* store.

# %%
# %%sql
# SELECT MAX(track_id) No_of_tracks
#   FROM track;
# Out:
# Done.
# [(3503,)]

# %% [markdown]
# As we can see there are a total of **3503** number of tracks with the store. Now we can calculate the number of tracks which are purchased Vs not purchased. For this purpose we will use *LEFT JOIN* operator on *track table* (this has all the tracks) and *invoice_line* (this has tracks which are sold).

# %%
# %%sql
# WITH TRACKS AS
# (SELECT t.track_id all_tracks, COUNT(il.track_id) purchased_tracks,
#         CASE
#         WHEN COUNT(il.track_id) == 0 THEN "Not Purchased"
#         ELSE "Purchased"
#         END AS Category
#    FROM track t
#  LEFT JOIN invoice_line il ON il.track_id = t.track_id
#  GROUP BY 1)
#
# SELECT COUNT(Category)
#   FROM TRACKS
#  WHERE Category = "Purchased";
# Out:
# Done.
# [(1806,)]

# %%
# %%sql
# WITH TRACKS AS
# (SELECT t.track_id all_tracks, COUNT(il.track_id) purchased_tracks,
#         CASE
#         WHEN COUNT(il.track_id) == 0 THEN "Not Purchased"
#         ELSE "Purchased"
#         END AS Category
#    FROM track t
#  LEFT JOIN invoice_line il ON il.track_id = t.track_id
#  GROUP BY 1)
#
# SELECT COUNT(Category)
#   FROM TRACKS
#  WHERE Category = "Not Purchased";
# Out:
# Done.
# [(1697,)]

# %% [markdown]
# From the above analysis we observe the following points:-
#
#  * Total number of tracks purchased is **1806**
#  * Number of tracks which are not purchased is **1697**
#
#  We can confirm that this analysis is correct by adding the above two numbers, as this amounts to total number of tracks the store owns i.e. 3503.

# %% [markdown]
# ### 6.3. Reflection of Range of Tracks on Sales Popularity

# %% [markdown]
# In this section we are going to see wether the *range of tracks* with *Chinook* store reflects its sales popularity. For this analysis we will compare the number of tracks the company has in each genre with it's sales value.

# %%
# %%sql
# SELECT g.name genre_name, COUNT(t.track_id) no_of_tracks, COUNT(il.track_id) quantity_sold, ROUND(CAST(COUNT(il.track_id) AS FLOAT) * 100.0 / CAST(COUNT(t.track_id) AS FLOAT), 2) perc_sales
#   FROM genre g
# INNER JOIN track t ON t.genre_id = g.genre_id
# LEFT JOIN invoice_line il ON il.track_id = t.track_id
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
# Done.
# [('Rock', 3017, 2635, 87.34),
#  ('Metal', 755, 619, 81.99),
#  ('Alternative & Punk', 648, 492, 75.93),
#  ('Latin', 627, 167, 26.63),
#  ('Jazz', 190, 121, 63.68),
#  ('R&B/Soul', 165, 159, 96.36),
#  ('Blues', 149, 124, 83.22),
#  ('Alternative', 123, 117, 95.12),
#  ('Classical', 105, 47, 44.76),
#  ('TV Shows', 93, 2, 2.15),
#  ('Pop', 86, 63, 73.26),
#  ('Easy Listening', 74, 74, 100.0),
#  ('Reggae', 71, 35, 49.3),
#  ('Drama', 64, 1, 1.56),
#  ('Electronica/Dance', 56, 55, 98.21),
#  ('Hip Hop/Rap', 47, 33, 70.21),
#  ('Soundtrack', 43, 5, 11.63),
#  ('Heavy Metal', 29, 8, 27.59),
#  ('World', 28, 0, 0.0),
#  ('Sci Fi & Fantasy', 26, 0, 0.0),
#  ('Comedy', 17, 0, 0.0),
#  ('Bossa Nova', 15, 0, 0.0),
#  ('Science Fiction', 13, 0, 0.0),
#  ('Rock And Roll', 12, 0, 0.0),
#  ('Opera', 1, 0, 0.0)]

# %% [markdown]
# As we can see the table above, there are total of *18* different genres.
#  - *Rock* tops the list with highest number of tracks i.e. *2635*. It has a good sales percentage is i.e.*~ 87%*. Next is *Metal* with *755* total number of tracks and *~ 82%* sales percentage, we can consider this also as a good sales value. Third is *Alternative & Punk* with *648* total number of tracks with only *~ 76%* of sales percentage, which is a moderate sales value.
#  - There are some genres with large number of tracks but low sales percentage. For e.g. *Latin* has *627* number of tracks and has only *~ 26%* sales value. *Classical*, *Heavy Metal*, *TV Shows*, *Reggae* have below *50%* sales percentage.
#  - There are some other genres where number of tracks are less but higher sales value. Examples are *Easy Listenng*, *R&B/Soul*, *Alternative*, *Blues* etc.
#
# Overall, we observe that the number of tracks does reflect the sales popularity with slight discrepancies.

# %% [markdown]
# ### 6.4. Effect of Protected and Non-protected Media Types on Popularity

# %% [markdown]
# In this section we will find out if *protected* and *non-protected media types* have any effect on the popularity. Here we have five different media types.
#
#  1. **Protected Media Types**
#     1. Protected AAC audio file
#     2. Protected MPEG-4 video file
#
#  2. **Non- Protected Media Types**
#     1. Purchased AAC audio file
#     2. MPEG audio file
#     2. AAC audio file

# %%
# %%sql
# SELECT mt.name media_type, COUNT(*) total_tracks, COUNT(il.quantity) track_sold, ROUND(CAST(COUNT(il.quantity) AS FLOAT) * 100.0/CAST(COUNT(t.track_id) AS FLOAT), 2) perc_sales
#   FROM media_type mt
# INNER JOIN track t ON t.media_type_id = mt.media_type_id
# LEFT JOIN invoice_line il ON il.track_id = t.track_id
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
# Done.
# [('MPEG audio file', 5652, 4259, 75.35),
#  ('Protected AAC audio file', 525, 439, 83.62),
#  ('Protected MPEG-4 video file', 214, 3, 1.4),
#  ('Purchased AAC audio file', 39, 35, 89.74),
#  ('AAC audio file', 24, 21, 87.5)]

# %% [markdown]
# Above table lists all the media types and thier sales percentage.
#
#  - Highest number of tracks the comany holds is *MPEG audio file* with *5652* number of tracks. Out of this *4259* tracks are sold i.e. *~ 75%*. Among other non-protected media types (*Purchased AAC audio file* and *AAC audio file*), the company holds fewer number of tracks and the sales percentage is above *85%*.
#  - The company holds *525 Protected AAC audio file* and it has *~ 83%* sales percentage. This is a good sales value. Company also holds *214 Protected MPEG-4 audio file* among this only *1.4%* of tracks are sold, this is way too low.
#
# We observe that among all the media-types *Protected MPEG-4 video file* is not popular among the consumers. Even though *MPEG audio file* sales percentage is good, not as high as other audio files. Otherwise, we do not see any effect on popularity between protected and non protected media types.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# In this project we answered business queries related to *Chinook Record Store* using *SQL* Database. Our analysis led to the following observations:-
#
#  * We found which genres sell best in the *USA*. Based on this we listed three albums to be added to the *Chinook store*. These are:-
#    * Red Tone
#    * Slim Jim Bites
#    * Meteor and the Girls
#  * We analyzed the performance of *Sales Support Agents*. And found that *Jane Peacock* and *Steve Johnson* are doing better than *Margaret Parker*. We also observed that the age impacts the performance as *Jane Peacock* is youngest of all and *Steve Johnson* is younger to *Margaret Parker*.
#  * We analyzed the sales data for customers from each country. We calculated *total number of customers*, *total value of sales*, *average value of sales per customer* and *average order value* for each country. We observed that *USA* is on top of the list with *13* customers and *~ \$1040* total value of sales. Next is *CANADA* with *8* customers and with *~ \$535* value of sales.
#  * We calculated the percentage of individual tracks and  the percentage of whole album purchased by customers. Our analysis led to the conclusion that the individual tracks purchases (~ 78%) are higher compared to album purchases (~ 22%). This can help the company in deciding whether to buy popular tracks from albums or to buy the whole album from record companies.
#  * We analyzed which artist is used in most playlists and found that *The Police* is used in most playlists.
#  * We calculated the number of tracks purchased Vs not purchased. Of all *3503* tracks, we found *1806* tracks purchased and *1697* tracks not purchased.
#  * We analyzed the sales popularity of range of tracks the *Chinook Store* owns. For this we calculated the number of tracks company owns in each genre and it's sales value. We observed that the number of tracks does reflect the sales popularity with slight discrepancies.
#  * We observed if different media types have any effect on popularity. We observe that among all the media-types *Protected MPEG-4 video file* is not popular among the consumers. Also *MPEG audio file* sales percentage is not as high as *Protected AAC audio files*, *Purchased AAC audio files* and *AAC audio files*. Otherwise, we do not see any effect on popularity between protected and non protected media types.
